# %%
using cMPO

# %%
m = XXZmodel_2D_helical(1.0, 5);

# %%
β = 16
D = 8
ψ0 = init_cmps(8, m, β);

# %%
res = adaptive_mera_update(m.Tmatrix * ψ0, D, β, options = MeraUpdateOptions(show_trace = true, maxiter= 100))
# Out:
# -----------------------------MERA update------------------------------
# step           θ                 loss_diff             fidelity
#
# ----  -------------------  --------------------   -------------------
#
#   1   3.1415926535897931   9.8999999649417744e+09   0.2024042023122037
#
#   2   0.0981747704246810   9.8999999649413986e+09   0.2024801938596016
#   3   0.0981747704246810   2.0902656059078595e-03   0.2029038738923417
#   4   0.0490873852123405   7.0809891576359973e-03   0.2043457328927788
#   5   0.0122718463030851   2.3859036850382154e-04   0.2043944936331821
#   6   0.0061359231515426   7.7036251013851142e-06   0.2043960682177988
#   7   0.0030679615757713   2.8480860564172872e-05   0.2044018896766173
#   8   0.0015339807878856   1.0660863978273483e-06   0.2044021075868077
#   9   0.0007669903939428   0.0000000000000000e+00   0.2044021075868077
# ...

# %%
res = adaptive_mera_update(m.Tmatrix * ψ0, D, β, options = MeraUpdateOptions(show_trace = true, maxiter= 100, interpolate = false))
# Out:
# -----------------------------MERA update------------------------------
# step           θ                 loss_diff             fidelity
#
# ----  -------------------  --------------------   -------------------
#
#   1   3.1415926535897931   9.8999999649417744e+09   0.2024042023122037
#
#   2   3.1415926535897931   9.8999999659287567e+09   0.0754359838169748
#
#   3   3.1415926535897931   2.0662729918899245e+00   0.0095544919793286
#
#   4   3.1415926535897931   2.8887543264522293e+00   0.1717029132212547
#   5   3.1415926535897931   1.6719672092705622e+00   0.0322590468187718
#
#   6   3.1415926535897931   1.1365079267610696e+00   0.1005149479415972
#
#   7   3.1415926535897931   2.8990417179674139e+00   0.0055359585681418
#
#   8   3.1415926535897931   3.4299971695331308e+00   0.1709313311693750
#
#   9   3.1415926535897931   2.2162370971421126e+00   0.0186346883074236
#  10   3.1415926535897931   2.2741532885335332e+00   0.1811233145478222
#
# ...

# %%
res2 = adaptive_mera_update(m.Tmatrix * ψ0, 10, β, options = MeraUpdateOptions(show_trace = true, maxiter= 100))
# Out:
# -----------------------------MERA update------------------------------
# step           θ                 loss_diff             fidelity
#
# ----  -------------------  --------------------   -------------------
#
#   1   3.1415926535897931   9.8999999645609035e+09   0.2962304651457457
#
#   2   0.0981747704246810   9.8999999645595169e+09   0.2966411528365925
#   3   0.0490873852123405   9.8217947838961095e-03   0.2995690564611911
#
#   4   0.0490873852123405   4.4226002025027356e-04   0.2997015731794313
#   5   0.0245436926061703   1.8591283450177798e-03   0.3002592751282914
#   6   0.0122718463030851   4.1889562849917183e-04   0.3003850787735179
#   7   0.0122718463030851   3.4890652195684879e-04   0.3004899033725302
#   8   0.0122718463030851   3.0261002308407114e-04   0.3005808483888691
#   9   0.0122718463030851   3.1470086069163017e-04   0.3006754563263833
#  10   0.0122718463030851   2.0392073395214538e-04   0.3007367765381376
# ...

# %%
res3 = adaptive_mera_update(m.Tmatrix * ψ0, 12, β, options = MeraUpdateOptions(show_trace = true, maxiter= 100))
# Out:
# -----------------------------MERA update------------------------------
# step           θ                 loss_diff             fidelity
#
# ----  -------------------  --------------------   -------------------
#
#   1   3.1415926535897931   9.8999999641780663e+09   0.4344033159650326
#   2   0.1963495408493621   9.8999999641729965e+09   0.4366112589039134
#   3   0.0981747704246810   8.0146303787245188e-03   0.4401245970099947
#   4   0.0981747704246810   7.5022579643047038e-04   0.4404549137268832
#   5   0.0490873852123405   1.3150303209897629e-02   0.4462852809204529
#   6   0.0245436926061703   1.9617140300098868e-03   0.4471616243039392
#   7   0.0245436926061703   8.3867917580704443e-04   0.4475368067533252
#   8   0.0245436926061703   3.5327568677701038e-04   0.4476949385565051
#   9   0.0245436926061703   7.6017517219639785e-04   0.4480353945202043
#  10   0.0245436926061703   9.0064578770920889e-05   0.4480757484564891
# ...

# %%
res4 = adaptive_mera_update(m.Tmatrix * ψ0, 14, β, options = MeraUpdateOptions(show_trace = true, maxiter= 500))
# Out:
# -----------------------------MERA update------------------------------
# step           θ                 loss_diff             fidelity
#
# ----  -------------------  --------------------   -------------------
#
#   1   3.1415926535897931   9.8999999637963390e+09   0.6363197331270435
#   2   0.1963495408493621   9.8999999637880440e+09   0.6416197379509972
#   3   0.0122718463030851   5.3690139046125296e-04   0.6419643169746516
#   4   0.0122718463030851   2.6051375638758145e-04   0.6421315792964554
#   5   0.0061359231515426   1.4604543139284942e-04   0.6422253665283963
#   6   0.0122718463030851   8.5167402367858358e-05   0.6422800655238509
#   7   0.0061359231515426   6.3514704486067330e-05   0.6423208610479541
#   8   0.0030679615757713   4.4608025667969287e-05   0.6423495143524897
#   9   0.0061359231515426   3.7390836617134937e-05   0.6423735327872638
#  10   0.0030679615757713   2.1585958087655399e-05   0.6423873991850784
# ...
